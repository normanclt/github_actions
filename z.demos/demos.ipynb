# %%
mylist = []
print(mylist)
# Out:
# []

# %%
mylist.append("This is an entry!")

# %%
new_string = "This is another entry!"

# %%
mylist[0] = (f"{mylist[0]} {new_string}")

# %%
print(mylist)
# Out:
# ['This is an entry! This is another entry!']
